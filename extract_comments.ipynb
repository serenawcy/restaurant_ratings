# %%
# concatenate all comments

# %%
import math
import random
import string
import re 
from  collections import Counter
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sps
from scipy.spatial.distance import cdist
import statistics
import scipy.stats as sps
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import time

# %%
import requests
from bs4 import BeautifulSoup
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
data1 = pd.read_csv("customer_comments1_r1.csv")

# %%
data2 = pd.read_csv("customer_comments1_r2.csv")

# %%
data3 = pd.read_csv("customer_comments1_r3.csv")

# %%
data4 = pd.read_csv("customer_comments2_round1.csv")
data5 = pd.read_csv("customer_comments2_round2.csv")
data6 = pd.read_csv("customer_comments2_round3.csv")

# %%
data7 = pd.read_csv("customer_comments3_round1.csv")

# %%
data8 = pd.read_csv("customer_comments3_round2.csv")

# %%
data9 = pd.read_csv("customer_comments3_round3.csv")

# %%
li = []
li.append(data1)
li.append(data2)
li.append(data3)
li.append(data4)
li.append(data5)
li.append(data6)
li.append(data7)
li.append(data8)
li.append(data9)

# %%
frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame
# Out:
#        Unnamed: 0                      id        time         rating  \
# 0               0  a-hVnSTC12MY5L3t9yOSJw    5/1/2020  4 star rating
# 1               1  a-hVnSTC12MY5L3t9yOSJw   8/13/2022  4 star rating
# 2               2  a-hVnSTC12MY5L3t9yOSJw   3/25/2022  1 star rating
# 3               3  a-hVnSTC12MY5L3t9yOSJw   5/18/2021  4 star rating
# 4               4  a-hVnSTC12MY5L3t9yOSJw   4/12/2022  3 star rating
# ...           ...                     ...         ...            ...
# 53374        3811  YYuuOeD_vkboZkZy1kTTrQ   10/9/2022  5 star rating
# 53375        3812  YYuuOeD_vkboZkZy1kTTrQ   2/21/2023  5 star rating
# 53376        3813  YYuuOeD_vkboZkZy1kTTrQ  12/19/2022  5 star rating
# 53377        3814  YYuuOeD_vkboZkZy1kTTrQ   12/8/2022  5 star rating
# 53378        3815  YYuuOeD_vkboZkZy1kTTrQ  12/16/2022  5 star rating
#
#                                                  comment
# 0      ordered delivery and was very happy with the f...
# 1      This is your run-of-the-mill Chinese takeout s...
# 2      Waited for 30 minutes and ask everyone at the ...
# 3      I like this place for American Chinese food. M...
# 4      Food is great. Kind of upset they changed the ...
# ...                                                  ...
# 53374  Casa Enrique never disappoints with their auth...
# 53375  We dined on a Monday night, and it was super b...
# 53376  Worth the hype. A Michelin started Mexican res...
# 53377  Casa Enrique is a tapas-style portion menu. Ev...
# 53378  Casa Enrique is truthy worthy of its Michelin ...
#
# [53379 rows x 5 columns]

# %%
frame2 = frame.drop_duplicates()

# %%
frame2
# Out:
#        Unnamed: 0                      id        time         rating  \
# 0               0  a-hVnSTC12MY5L3t9yOSJw    5/1/2020  4 star rating
# 1               1  a-hVnSTC12MY5L3t9yOSJw   8/13/2022  4 star rating
# 2               2  a-hVnSTC12MY5L3t9yOSJw   3/25/2022  1 star rating
# 3               3  a-hVnSTC12MY5L3t9yOSJw   5/18/2021  4 star rating
# 4               4  a-hVnSTC12MY5L3t9yOSJw   4/12/2022  3 star rating
# ...           ...                     ...         ...            ...
# 53374        3811  YYuuOeD_vkboZkZy1kTTrQ   10/9/2022  5 star rating
# 53375        3812  YYuuOeD_vkboZkZy1kTTrQ   2/21/2023  5 star rating
# 53376        3813  YYuuOeD_vkboZkZy1kTTrQ  12/19/2022  5 star rating
# 53377        3814  YYuuOeD_vkboZkZy1kTTrQ   12/8/2022  5 star rating
# 53378        3815  YYuuOeD_vkboZkZy1kTTrQ  12/16/2022  5 star rating
#
#                                                  comment
# 0      ordered delivery and was very happy with the f...
# 1      This is your run-of-the-mill Chinese takeout s...
# 2      Waited for 30 minutes and ask everyone at the ...
# 3      I like this place for American Chinese food. M...
# 4      Food is great. Kind of upset they changed the ...
# ...                                                  ...
# 53374  Casa Enrique never disappoints with their auth...
# 53375  We dined on a Monday night, and it was super b...
# 53376  Worth the hype. A Michelin started Mexican res...
# 53377  Casa Enrique is a tapas-style portion menu. Ev...
# 53378  Casa Enrique is truthy worthy of its Michelin ...
#
# [53377 rows x 5 columns]

# %%
# select comments after 2022/1/1

# %%
import datetime

# %%
temp_df = frame2.copy()

# %%
temp_df['time'] = pd.to_datetime(temp_df['time'])
date = np.datetime64(datetime.date(2022, 1, 1))
date_df = temp_df[temp_df['time'] >= date]

# %%
date_df
# Out:
#        Unnamed: 0                      id       time         rating  \
# 1               1  a-hVnSTC12MY5L3t9yOSJw 2022-08-13  4 star rating
# 2               2  a-hVnSTC12MY5L3t9yOSJw 2022-03-25  1 star rating
# 4               4  a-hVnSTC12MY5L3t9yOSJw 2022-04-12  3 star rating
# 5               5  a-hVnSTC12MY5L3t9yOSJw 2022-03-04  1 star rating
# 10             10  znlol6dCKwjoXpZZwV_ZOg 2022-10-13  5 star rating
# ...           ...                     ...        ...            ...
# 53374        3811  YYuuOeD_vkboZkZy1kTTrQ 2022-10-09  5 star rating
# 53375        3812  YYuuOeD_vkboZkZy1kTTrQ 2023-02-21  5 star rating
# 53376        3813  YYuuOeD_vkboZkZy1kTTrQ 2022-12-19  5 star rating
# 53377        3814  YYuuOeD_vkboZkZy1kTTrQ 2022-12-08  5 star rating
# 53378        3815  YYuuOeD_vkboZkZy1kTTrQ 2022-12-16  5 star rating
#
#                                                  comment
# 1      This is your run-of-the-mill Chinese takeout s...
# 2      Waited for 30 minutes and ask everyone at the ...
# 4      Food is great. Kind of upset they changed the ...
# 5      They lie foos coming lady I'm still waiting re...
# 10     Good food that is quick and authentic! I order...
# ...                                                  ...
# 53374  Casa Enrique never disappoints with their auth...
# 53375  We dined on a Monday night, and it was super b...
# 53376  Worth the hype. A Michelin started Mexican res...
# 53377  Casa Enrique is a tapas-style portion menu. Ev...
# 53378  Casa Enrique is truthy worthy of its Michelin ...
#
# [23198 rows x 5 columns]

# %%
date_df.to_csv('date_df.csv')

# %%
# select comments related to hygiene

# %%
hygiene_keywords = [
    "cleanliness",
    "clean",
    "dirty",
    "sanitary",
    "hygienic",
    "disinfect",
    "germ-free",
    "sterile",
    "bacteria",
    "contamination",
    "health inspection",
    "filthy",
    "grime",
    "grease",
    "dust",
    "pest",
    "rodent",
    "insect",
    "mold",
    "mildew",
    "odor",
    "smell",
    "trash",
    "garbage",
    "litter",
    "stain",
    "unsanitary",
    "spoiled",
    "rotten",
    "food poisoning"
]

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/serenawang/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
 nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/serenawang/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
hygiene_rows = []
for index, row in date_df.iterrows():
    comment = row['comment']
    for keyword in hygiene_keywords:
        for word in nltk.word_tokenize(comment):
            lemma = lemmatizer.lemmatize(word.lower())
            if keyword == lemma:
                hygiene_rows.append(row)

# %%
hygiene_df = pd.DataFrame(hygiene_rows)

# %%
hygiene_df
# Out:
#        Unnamed: 0                      id       time         rating  \
# 23             23  9dqJrTzx0GvBNb-J0VyeGg 2022-12-18  5 star rating
# 24             24  9dqJrTzx0GvBNb-J0VyeGg 2022-01-23  2 star rating
# 67             67  qrncvjkiKN5Z-JC06ygy6A 2022-12-13  2 star rating
# 67             67  qrncvjkiKN5Z-JC06ygy6A 2022-12-13  2 star rating
# 78             78  vpkTNjq9dRh9rT3Nh0pe-A 2023-02-27  5 star rating
# ...           ...                     ...        ...            ...
# 53207        3644  5YnysgHnTQMouHqal8UN8Q 2023-02-14  3 star rating
# 53207        3644  5YnysgHnTQMouHqal8UN8Q 2023-02-14  3 star rating
# 53207        3644  5YnysgHnTQMouHqal8UN8Q 2023-02-14  3 star rating
# 53208        3645  5YnysgHnTQMouHqal8UN8Q 2022-07-25  5 star rating
# 53231        3668  hGksyTiHBBdrhbiVjXzWVw 2022-04-04  1 star rating
#
#                                                  comment
# 23     Clean, modern, super friendly staff. Everythin...
# 24     Strawberry cake* - is delicious but I found a ...
# 67     I don't know where to begin. Let's just say I ...
# 67     I don't know where to begin. Let's just say I ...
# 78     My cousins from out of town were visiting and ...
# ...                                                  ...
# 53207  I got the power shake, (strawberry, banana and...
# 53207  I got the power shake, (strawberry, banana and...
# 53207  I got the power shake, (strawberry, banana and...
# 53208  Honestly, this place knows how to make a tuna ...
# 53231  This place was extremely rude. I'm staying at ...
#
# [1729 rows x 5 columns]

# %%
hygiene_df.to_csv("hygiene_df.csv")

# %%
# calculate average for both datasets

# %%
temp_rows1 = []
for index, row in hygiene_df.iterrows():
    rating_str = row['rating']
    rating_int = int(rating_str.split(' ')[0])
    row['rating'] = rating_int
    temp_rows1.append(row)

# %%
new_hygiene_df = pd.DataFrame(temp_rows1)

# %%
new_hygiene_df
# Out:
#        Unnamed: 0                      id       time  rating  \
# 23             23  9dqJrTzx0GvBNb-J0VyeGg 2022-12-18       5
# 24             24  9dqJrTzx0GvBNb-J0VyeGg 2022-01-23       2
# 67             67  qrncvjkiKN5Z-JC06ygy6A 2022-12-13       2
# 67             67  qrncvjkiKN5Z-JC06ygy6A 2022-12-13       2
# 78             78  vpkTNjq9dRh9rT3Nh0pe-A 2023-02-27       5
# ...           ...                     ...        ...     ...
# 53207        3644  5YnysgHnTQMouHqal8UN8Q 2023-02-14       3
# 53207        3644  5YnysgHnTQMouHqal8UN8Q 2023-02-14       3
# 53207        3644  5YnysgHnTQMouHqal8UN8Q 2023-02-14       3
# 53208        3645  5YnysgHnTQMouHqal8UN8Q 2022-07-25       5
# 53231        3668  hGksyTiHBBdrhbiVjXzWVw 2022-04-04       1
#
#                                                  comment
# 23     Clean, modern, super friendly staff. Everythin...
# 24     Strawberry cake* - is delicious but I found a ...
# 67     I don't know where to begin. Let's just say I ...
# 67     I don't know where to begin. Let's just say I ...
# 78     My cousins from out of town were visiting and ...
# ...                                                  ...
# 53207  I got the power shake, (strawberry, banana and...
# 53207  I got the power shake, (strawberry, banana and...
# 53207  I got the power shake, (strawberry, banana and...
# 53208  Honestly, this place knows how to make a tuna ...
# 53231  This place was extremely rude. I'm staying at ...
#
# [1729 rows x 5 columns]

# %%
grouped_hygiene_df = new_hygiene_df.groupby('id')['rating'].mean()

# %%
grouped_hygiene_df.head(10)
# Out:
# id
# -J8VuX3wGrYSOBu2G0hMsw    3.666667
# -KfM32STVYND4v_9l1YRug    4.000000
# -OixbLnFLCzQclxCSbUQ8w    5.000000
# -OmMU5ZjOKlB9K6kSCFv5A    4.000000
# -Q8MYIWoE4EsGQtudIOY0w    2.333333
# -ReVBdHXjJ4qH9Xl2MDq3A    5.000000
# -YazuZbXAM_NOny8LpLQpQ    5.000000
# -f3GB9AGUqLFkXorluMFTQ    5.000000
# -jdadX3fGXA2TDapnufYFA    4.000000
# -kVueEw_fyO1Q2Gkmj6Few    4.000000
# Name: rating, dtype: float64

# %%
grouped_hygiene_df.to_csv('grouped_hygiene_df.csv')
# grouped_hygiene_df

# %%
temp_rows2 = []
for index, row in date_df.iterrows():
    rating_str = row['rating']
    rating_int = int(rating_str.split(' ')[0])
    row['rating'] = rating_int
    temp_rows2.append(row)

# %%
new_date_df = pd.DataFrame(temp_rows2)

# %%
grouped_date_df = new_hygiene_df.groupby('id')['rating'].mean()

# %%
grouped_date_df.to_csv('grouped_date_df.csv')
